# %%
import pandas as pd

# %%
df = pd.read_csv("TestCricketAvgData.csv")
df
# Out:
#                       Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0           DG Bradman (AUS)  1928-1948   52    80  10   6996   334  99.94
# 1             AC Voges (AUS)  2015-2016   20    31   7   1485  269*  61.87
# 2            RG Pollock (SA)  1963-1970   23    41   4   2256   274  60.97
# 3            GA Headley (WI)  1930-1954   22    40   4   2190  270*  60.83
# 4            GA Headley (WI)  1930-1954   22    40   4   2190  270*  60.83
# 5          H Sutcliffe (ENG)  1924-1935   54    84   9   4555   194  60.73
# 6            E Paynter (ENG)  1931-1939   20    31   5   1540   243  59.23
# 7        KF Barrington (ENG)  1955-1968   82   131  15   6806   256  58.67
# 8             ED Weekes (WI)  1948-1958   48    81   5   4455   207  58.61
# 9           WR Hammond (ENG)  1927-1947   85   140  16   7249  336*  58.45
# 10            GS Sobers (WI)  1954-1974   93   160  21   8032  365*  57.78
# ...

# %%
#Rename columns

# %%
df = df.rename(columns = {"Mat": "Matches", "Inns": "Innings", "NO": "Not_Outs", "HS": "High_Score", "Ave": "Average_Score", "BF": "Balls_Faced", "SR": "Batting_Strike_Rate"})

# %%
#finding the null values

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Innings                False
# Not_Outs               False
# Runs                   False
# High_Score             False
# Average_Score          False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
#finding the NaN values in specific field

# %%
df[df['Balls_Faced'].isna() == True]
# Out:
#                   Player       Span  Matches  Innings  Not_Outs  Runs  \
# 8         ED Weekes (WI)  1948-1958       48       81         5  4455
# 14       CL Walcott (WI)  1948-1960       44       74         7  3798
# 59  Hon.FS Jackson (ENG)  1893-1905       20       33         4  1415
#
#    High_Score  Average_Score Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 8         207          58.61         NaN                  NaN   15  19  6
# 14        220          56.68         NaN                  NaN   15  14  1
# 59       144*          48.79         NaN                  NaN    5   6  3
#
#       4s  6s
# 8   258+   2
# 14  107+  11
# 59   51+   0

# %%
#replacing 0 for null values

# %%
df["Balls_Faced"] = df["Balls_Faced"].fillna(0)

# %%
df["Batting_Strike_Rate"] = df["Batting_Strike_Rate"].fillna(0)

# %%
df[df['Player']=="ED Weekes (WI)"]
# Out:
#            Player       Span  Matches  Innings  Not_Outs  Runs High_Score  \
# 8  ED Weekes (WI)  1948-1958       48       81         5  4455        207
#
#    Average_Score Balls_Faced  Batting_Strike_Rate  100  50  0    4s 6s
# 8          58.61           0                  0.0   15  19  6  258+  2

# %%
#finding the duplicates values

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42     True
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55     True
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# dtype: bool

# %%
df[df['Player'].duplicated() == 1]
# Out:
#                 Player       Span  Matches  Innings  Not_Outs   Runs  \
# 4      GA Headley (WI)  1930-1954       22       40         4   2190
# 18  JH Kallis (ICC/SA)  1995-2013      166      280        40  13289
# 42       JE Root (ENG)  2012-2024      146      267        22  12402
# 55       V Kohli (IND)  2011-2024      113      191        11   8848
#
#    High_Score  Average_Score Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 4        270*          60.83        416+                56.00   10   5   2
# 18        224          55.37       28903                45.97   45  58  16
# 42        254          50.62       21785                56.92   34  64  12
# 55       254*          49.15       15924                55.56   29  30  14
#
#       4s  6s
# 4   104+   1
# 18  1488  97
# 42  1343  44
# 55   991  26

# %%
df[df['Player'].isin(["GA Headley (WI)","JH Kallis (ICC/SA)","JE Root (ENG)","V Kohli (IND)"])]
# Out:
#                 Player       Span  Matches  Innings  Not_Outs   Runs  \
# 3      GA Headley (WI)  1930-1954       22       40         4   2190
# 4      GA Headley (WI)  1930-1954       22       40         4   2190
# 17  JH Kallis (ICC/SA)  1995-2013      166      280        40  13289
# 18  JH Kallis (ICC/SA)  1995-2013      166      280        40  13289
# 41       JE Root (ENG)  2012-2024      146      267        22  12402
# 42       JE Root (ENG)  2012-2024      146      267        22  12402
# 54       V Kohli (IND)  2011-2024      113      191        11   8848
# 55       V Kohli (IND)  2011-2024      113      191        11   8848
#
#    High_Score  Average_Score Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 3        270*          60.83        416+                56.00   10   5   2
# 4        270*          60.83        416+                56.00   10   5   2
# 17        224          55.37       28903                45.97   45  58  16
# ...

# %%
#drop duplicate values

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                       Player       Span  Matches  Innings  Not_Outs   Runs  \
# 0           DG Bradman (AUS)  1928-1948       52       80        10   6996
# 1             AC Voges (AUS)  2015-2016       20       31         7   1485
# 2            RG Pollock (SA)  1963-1970       23       41         4   2256
# 3            GA Headley (WI)  1930-1954       22       40         4   2190
# 5          H Sutcliffe (ENG)  1924-1935       54       84         9   4555
# 6            E Paynter (ENG)  1931-1939       20       31         5   1540
# 7        KF Barrington (ENG)  1955-1968       82      131        15   6806
# 8             ED Weekes (WI)  1948-1958       48       81         5   4455
# 9           WR Hammond (ENG)  1927-1947       85      140        16   7249
# 10            GS Sobers (WI)  1954-1974       93      160        21   8032
# 11        KC Sangakkara (SL)  2000-2015      134      233        17  12400
# ...

# %%
#split the SPan fields

# %%
df
# Out:
#                       Player       Span  Matches  Innings  Not_Outs   Runs  \
# 0           DG Bradman (AUS)  1928-1948       52       80        10   6996
# 1             AC Voges (AUS)  2015-2016       20       31         7   1485
# 2            RG Pollock (SA)  1963-1970       23       41         4   2256
# 3            GA Headley (WI)  1930-1954       22       40         4   2190
# 5          H Sutcliffe (ENG)  1924-1935       54       84         9   4555
# 6            E Paynter (ENG)  1931-1939       20       31         5   1540
# 7        KF Barrington (ENG)  1955-1968       82      131        15   6806
# 8             ED Weekes (WI)  1948-1958       48       81         5   4455
# 9           WR Hammond (ENG)  1927-1947       85      140        16   7249
# 10            GS Sobers (WI)  1954-1974       93      160        21   8032
# 11        KC Sangakkara (SL)  2000-2015      134      233        17  12400
# ...

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2015, 2016]
# 2     [1963, 1970]
# 3     [1930, 1954]
# 5     [1924, 1935]
# 6     [1931, 1939]
# 7     [1955, 1968]
# 8     [1948, 1958]
# 9     [1927, 1947]
# 10    [1954, 1974]
# 11    [2000, 2015]
# 12    [2010, 2024]
# 13    [1908, 1930]
# 14    [1948, 1960]
# 15    [1937, 1955]
# 16    [2022, 2024]
# 17    [1995, 2013]
# 19    [1921, 1929]
# 20    [2010, 2024]
# 21    [1968, 1973]
# 22    [1993, 1995]
# 23    [1970, 1984]
# 24    [1935, 1951]
# 25    [1989, 2013]
# 26    [2022, 2024]
# 27    [1990, 2006]
# 28    [1976, 1993]
# 29    [1996, 2012]
# 30    [1998, 2010]
# 31    [2000, 2017]
# 32    [1995, 2012]
# 33    [1920, 1929]
# 34    [1992, 2002]
# 35    [2005, 2013]
# 36    [1994, 2015]
# 37    [1971, 1987]
# 38    [1985, 2004]
# 39    [1994, 2009]
# 40    [2004, 2018]
# 41    [2012, 2024]
# 43    [1978, 1994]
# 44    [2019, 2024]
# 45    [1974, 1991]
# 46    [1937, 1957]
# 47    [1997, 2014]
# 48    [1992, 2007]
# 49    [2018, 2024]
# ...

# %%
df['Span'].str.split(pat = '-').str[1]
# Out:
# 0     1948
# 1     2016
# 2     1970
# 3     1954
# 5     1935
# 6     1939
# 7     1968
# 8     1958
# 9     1947
# 10    1974
# 11    2015
# 12    2024
# 13    1930
# 14    1960
# 15    1955
# 16    2024
# 17    2013
# 19    1929
# 20    2024
# 21    1973
# 22    1995
# 23    1984
# 24    1951
# 25    2013
# 26    2024
# 27    2006
# 28    1993
# 29    2012
# 30    2010
# 31    2017
# 32    2012
# 33    1929
# 34    2002
# 35    2013
# 36    2015
# 37    1987
# 38    2004
# 39    2009
# 40    2018
# 41    2024
# 43    1994
# 44    2024
# 45    1991
# 46    1957
# 47    2014
# 48    2007
# 49    2024
# 50    1963
# 51    1928
# 52    2013
# 53    2021
# 54    2024
# 56    2015
# 57    1966
# 58    1949
# 59    1905
# 60    2013
# 61    1963
# 62    1981
# 63    2014
# 64    1934
# 65    1938
# 66    1934
# Name: Span, dtype: object

# %%
df["Start_Year"] = df["Span"].str.split(pat = '-').str[0]

# %%
df["End_Year"] = df["Span"].str.split(pat = '-').str[1]

# %%
df
# Out:
#                       Player       Span  Matches  Innings  Not_Outs   Runs  \
# 0           DG Bradman (AUS)  1928-1948       52       80        10   6996
# 1             AC Voges (AUS)  2015-2016       20       31         7   1485
# 2            RG Pollock (SA)  1963-1970       23       41         4   2256
# 3            GA Headley (WI)  1930-1954       22       40         4   2190
# 5          H Sutcliffe (ENG)  1924-1935       54       84         9   4555
# 6            E Paynter (ENG)  1931-1939       20       31         5   1540
# 7        KF Barrington (ENG)  1955-1968       82      131        15   6806
# 8             ED Weekes (WI)  1948-1958       48       81         5   4455
# 9           WR Hammond (ENG)  1927-1947       85      140        16   7249
# 10            GS Sobers (WI)  1954-1974       93      160        21   8032
# 11        KC Sangakkara (SL)  2000-2015      134      233        17  12400
# ...

# %%
#drop Span field

# %%
df = df.drop(['Span'], axis = 1)

# %%
df.head()
# Out:
#               Player  Matches  Innings  Not_Outs  Runs High_Score  \
# 0   DG Bradman (AUS)       52       80        10  6996        334
# 1     AC Voges (AUS)       20       31         7  1485       269*
# 2    RG Pollock (SA)       23       41         4  2256        274
# 3    GA Headley (WI)       22       40         4  2190       270*
# 5  H Sutcliffe (ENG)       54       84         9  4555        194
#
#    Average_Score Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s  \
# 0          99.94       9800+                58.60   29  13  7  626+   6
# 1          61.87        2667                55.68    5   4  2   186   5
# 2          60.97       1707+                54.48    7  11  1  246+  11
# 3          60.83        416+                56.00   10   5  2  104+   1
# 5          60.73       6558+                34.59   16  23  2  202+   6
#
#   Start_Year End_Year
# 0       1928     1948
# 1       2015     2016
# 2       1963     1970
# 3       1930     1954
# ...

# %%
df
# Out:
#                       Player  Matches  Innings  Not_Outs   Runs High_Score  \
# 0           DG Bradman (AUS)       52       80        10   6996        334
# 1             AC Voges (AUS)       20       31         7   1485       269*
# 2            RG Pollock (SA)       23       41         4   2256        274
# 3            GA Headley (WI)       22       40         4   2190       270*
# 5          H Sutcliffe (ENG)       54       84         9   4555        194
# 6            E Paynter (ENG)       20       31         5   1540        243
# 7        KF Barrington (ENG)       82      131        15   6806        256
# 8             ED Weekes (WI)       48       81         5   4455        207
# 9           WR Hammond (ENG)       85      140        16   7249       336*
# 10            GS Sobers (WI)       93      160        21   8032       365*
# 11        KC Sangakkara (SL)      134      233        17  12400        319
# ...

# %%
df["Player"].str.split(pat = '(')
# Out:
# 0             [DG Bradman , AUS)]
# 1               [AC Voges , AUS)]
# 2              [RG Pollock , SA)]
# 3              [GA Headley , WI)]
# 5            [H Sutcliffe , ENG)]
# 6              [E Paynter , ENG)]
# 7          [KF Barrington , ENG)]
# 8               [ED Weekes , WI)]
# 9             [WR Hammond , ENG)]
# 10              [GS Sobers , WI)]
# 11          [KC Sangakkara , SL)]
# 12             [SPD Smith , AUS)]
# 13              [JB Hobbs , ENG)]
# 14             [CL Walcott , WI)]
# 15              [L Hutton , ENG)]
# 16          [Saud Shakeel , PAK)]
# 17          [JH Kallis , ICC/SA)]
# 19          [GE Tyldesley , ENG)]
# 20          [KS Williamson , NZ)]
# 21               [CA Davis , WI)]
# 22             [VG Kambli , IND)]
# 23           [GS Chappell , AUS)]
# 24              [AD Nourse , SA)]
# 25          [SR Tendulkar , IND)]
# 26              [HC Brook , ENG)]
# 27            [BC Lara , ICC/WI)]
# 28         [Javed Miandad , PAK)]
# ...

# %%
df["Country"] = df["Player"].str.split(pat = '(').str[1]

# %%
df["Country"]
# Out:
# 0         AUS)
# 1         AUS)
# 2          SA)
# 3          WI)
# 5         ENG)
# 6         ENG)
# 7         ENG)
# 8          WI)
# 9         ENG)
# 10         WI)
# 11         SL)
# 12        AUS)
# 13        ENG)
# 14         WI)
# 15        ENG)
# 16        PAK)
# 17     ICC/SA)
# 19        ENG)
# 20         NZ)
# 21         WI)
# 22        IND)
# 23        AUS)
# 24         SA)
# 25        IND)
# 26        ENG)
# 27     ICC/WI)
# 28        PAK)
# 29    ICC/IND)
# 30        PAK)
# 31        PAK)
# 32        AUS)
# 33        AUS)
# 34        ZIM)
# 35        AUS)
# 36         WI)
# 37        IND)
# 38        AUS)
# 39        AUS)
# 40         SA)
# 41        ENG)
# 43        AUS)
# 44         NZ)
# 45         WI)
# 46        ENG)
# 47         SL)
# 48    ICC/PAK)
# 49        AUS)
# 50         WI)
# 51        ENG)
# 52    ICC/IND)
# 53        PAK)
# 54        IND)
# 56        AUS)
# 57         SA)
# 58         SA)
# 59        ENG)
# 60         SL)
# 61        AUS)
# ...

# %%
df["Country"].str.split(pat = ')')
# Out:
# 0         [AUS, ]
# 1         [AUS, ]
# 2          [SA, ]
# 3          [WI, ]
# 5         [ENG, ]
# 6         [ENG, ]
# 7         [ENG, ]
# 8          [WI, ]
# 9         [ENG, ]
# 10         [WI, ]
# 11         [SL, ]
# 12        [AUS, ]
# 13        [ENG, ]
# 14         [WI, ]
# 15        [ENG, ]
# 16        [PAK, ]
# 17     [ICC/SA, ]
# 19        [ENG, ]
# 20         [NZ, ]
# 21         [WI, ]
# 22        [IND, ]
# 23        [AUS, ]
# 24         [SA, ]
# 25        [IND, ]
# 26        [ENG, ]
# 27     [ICC/WI, ]
# 28        [PAK, ]
# 29    [ICC/IND, ]
# 30        [PAK, ]
# 31        [PAK, ]
# 32        [AUS, ]
# 33        [AUS, ]
# 34        [ZIM, ]
# 35        [AUS, ]
# 36         [WI, ]
# 37        [IND, ]
# 38        [AUS, ]
# 39        [AUS, ]
# 40         [SA, ]
# 41        [ENG, ]
# 43        [AUS, ]
# 44         [NZ, ]
# 45         [WI, ]
# 46        [ENG, ]
# 47         [SL, ]
# 48    [ICC/PAK, ]
# 49        [AUS, ]
# 50         [WI, ]
# 51        [ENG, ]
# 52    [ICC/IND, ]
# ...

# %%
df["Country"] = df["Country"].str.split(pat = ')').str[0]

# %%
df["Country"]
# Out:
# 0         AUS
# 1         AUS
# 2          SA
# 3          WI
# 5         ENG
# 6         ENG
# 7         ENG
# 8          WI
# 9         ENG
# 10         WI
# 11         SL
# 12        AUS
# 13        ENG
# 14         WI
# 15        ENG
# 16        PAK
# 17     ICC/SA
# 19        ENG
# 20         NZ
# 21         WI
# 22        IND
# 23        AUS
# 24         SA
# 25        IND
# 26        ENG
# 27     ICC/WI
# 28        PAK
# 29    ICC/IND
# 30        PAK
# 31        PAK
# 32        AUS
# 33        AUS
# 34        ZIM
# 35        AUS
# 36         WI
# 37        IND
# 38        AUS
# 39        AUS
# 40         SA
# 41        ENG
# 43        AUS
# 44         NZ
# 45         WI
# 46        ENG
# 47         SL
# 48    ICC/PAK
# 49        AUS
# 50         WI
# 51        ENG
# 52    ICC/IND
# 53        PAK
# 54        IND
# 56        AUS
# 57         SA
# 58         SA
# 59        ENG
# 60         SL
# 61        AUS
# 62        AUS
# 63     ICC/SA
# 64        AUS
# 65        AUS
# ...

# %%
df["Player"] = df["Player"].str.split(pat = '(').str[0]

# %%
df.head()
# Out:
#          Player  Matches  Innings  Not_Outs  Runs High_Score  Average_Score  \
# 0   DG Bradman        52       80        10  6996        334          99.94
# 1     AC Voges        20       31         7  1485       269*          61.87
# 2   RG Pollock        23       41         4  2256        274          60.97
# 3   GA Headley        22       40         4  2190       270*          60.83
# 5  H Sutcliffe        54       84         9  4555        194          60.73
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0    4s  6s Start_Year End_Year  \
# 0       9800+                58.60   29  13  7  626+   6       1928     1948
# 1        2667                55.68    5   4  2   186   5       2015     2016
# 2       1707+                54.48    7  11  1  246+  11       1963     1970
# 3        416+                56.00   10   5  2  104+   1       1930     1954
# 5       6558+                34.59   16  23  2  202+   6       1924     1935
#
#   Country
# 0     AUS
# 1     AUS
# 2      SA
# ...

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Innings                  int64
# Not_Outs                 int64
# Runs                     int64
# High_Score              object
# Average_Score          float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Start_Year              object
# End_Year                object
# Country                 object
# dtype: object

# %%
df["High_Score"].str.split(pat = '*')
# Out:
# 0       [334]
# 1     [269, ]
# 2       [274]
# 3     [270, ]
# 5       [194]
# 6       [243]
# 7       [256]
# 8       [207]
# 9     [336, ]
# 10    [365, ]
# 11      [319]
# 12      [239]
# 13      [211]
# 14      [220]
# 15      [364]
# 16    [208, ]
# 17      [224]
# 19      [122]
# 20      [251]
# 21      [183]
# 22      [227]
# 23    [247, ]
# 24      [231]
# 25    [248, ]
# 26      [186]
# 27    [400, ]
# 28    [280, ]
# 29      [270]
# 30      [223]
# 31      [313]
# 32      [257]
# 33    [201, ]
# 34    [232, ]
# 35      [195]
# 36    [203, ]
# 37    [236, ]
# 38      [200]
# 39      [380]
# 40    [278, ]
# 41      [254]
# 43      [205]
# 44      [190]
# 45      [291]
# 46      [278]
# 47      [374]
# 48      [329]
# 49      [215]
# 50      [261]
# 51    [182, ]
# 52      [319]
# 53    [215, ]
# 54    [254, ]
# 56    [329, ]
# 57    [144, ]
# 58    [189, ]
# 59    [144, ]
# 60      [231]
# 61      [205]
# 62      [250]
# 63      [277]
# 64      [266]
# 65      [232]
# ...

# %%
df["High_Score"] = df["High_Score"].str.split(pat = '*').str[0]

# %%
df["High_Score"]
# Out:
# 0     334
# 1     269
# 2     274
# 3     270
# 5     194
# 6     243
# 7     256
# 8     207
# 9     336
# 10    365
# 11    319
# 12    239
# 13    211
# 14    220
# 15    364
# 16    208
# 17    224
# 19    122
# 20    251
# 21    183
# 22    227
# 23    247
# 24    231
# 25    248
# 26    186
# 27    400
# 28    280
# 29    270
# 30    223
# 31    313
# 32    257
# 33    201
# 34    232
# 35    195
# 36    203
# 37    236
# 38    200
# 39    380
# 40    278
# 41    254
# 43    205
# 44    190
# 45    291
# 46    278
# 47    374
# 48    329
# 49    215
# 50    261
# 51    182
# 52    319
# 53    215
# 54    254
# 56    329
# 57    144
# 58    189
# 59    144
# 60    231
# 61    205
# 62    250
# 63    277
# 64    266
# 65    232
# 66    127
# Name: High_Score, dtype: object

# %%
#Change the data type

# %%
df["High_Score"] = df["High_Score"].astype("int")

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Innings                  int64
# Not_Outs                 int64
# Runs                     int64
# High_Score               int32
# Average_Score          float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Start_Year              object
# End_Year                object
# Country                 object
# dtype: object

# %%
df["Start_Year"] = df["Start_Year"].astype("int")

# %%
df["End_Year"] = df["End_Year"].astype("int")

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Innings                  int64
# Not_Outs                 int64
# Runs                     int64
# High_Score               int32
# Average_Score          float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Start_Year               int32
# End_Year                 int32
# Country                 object
# dtype: object

# %%
# df["6s"] = df["6s"].astype("float")
df
# Out:
#                Player  Matches  Innings  Not_Outs   Runs  High_Score  \
# 0         DG Bradman        52       80        10   6996         334
# 1           AC Voges        20       31         7   1485         269
# 2         RG Pollock        23       41         4   2256         274
# 3         GA Headley        22       40         4   2190         270
# 5        H Sutcliffe        54       84         9   4555         194
# 6          E Paynter        20       31         5   1540         243
# 7      KF Barrington        82      131        15   6806         256
# 8          ED Weekes        48       81         5   4455         207
# 9         WR Hammond        85      140        16   7249         336
# 10         GS Sobers        93      160        21   8032         365
# 11     KC Sangakkara       134      233        17  12400         319
# 12         SPD Smith       109      195        25   9685         239
# 13          JB Hobbs        61      102         7   5410         211
# ...

# %%
df['6s'].str.split(pat = '+').str[0]
# Out:
# 0      6
# 1      5
# 2     11
# 3      1
# 5      6
# 6      4
# 7     27
# 8      2
# 9     27
# 10    32
# 11    51
# 12    54
# 13     8
# 14    11
# 15     7
# 16     1
# 17    97
# 19     2
# 20    24
# 21     1
# 22     6
# 23    16
# 24     6
# 25    69
# 26    26
# 27    88
# 28    48
# 29    21
# 30    51
# 31    70
# 32    73
# 33     3
# 34    20
# 35    39
# 36    36
# 37    26
# 38    20
# 39    82
# 40    64
# 41    44
# 43    28
# 44    29
# 45    84
# 46     3
# 47    61
# 48    48
# 49    12
# 50    11
# 51     0
# 52    91
# 53     5
# 54    26
# 56    39
# 57    20
# 58     1
# 59     0
# 60     7
# 61     1
# 62    23
# 63    24
# 64     0
# 65     5
# 66     0
# Name: 6s, dtype: object

# %%
df['6s']
# Out:
# 0       6
# 1       5
# 2      11
# 3       1
# 5       6
# 6       4
# 7      27
# 8       2
# 9      27
# 10    32+
# 11     51
# 12     54
# 13      8
# 14     11
# 15      7
# 16      1
# 17     97
# 19      2
# 20     24
# 21      1
# 22      6
# 23     16
# 24      6
# 25     69
# 26     26
# 27     88
# 28     48
# 29     21
# 30     51
# 31     70
# 32     73
# 33      3
# 34     20
# 35     39
# 36     36
# 37     26
# 38     20
# 39     82
# 40     64
# 41     44
# 43     28
# 44     29
# 45     84
# 46      3
# 47     61
# 48     48
# 49     12
# 50     11
# 51      0
# 52     91
# 53      5
# 54     26
# 56     39
# 57     20
# 58      1
# 59      0
# 60      7
# 61      1
# 62     23
# 63     24
# 64      0
# 65     5+
# 66      0
# Name: 6s, dtype: object

# %%
df['6s'] = df['6s'].str.split(pat = '+').str[0]

# %%
df
# Out:
#                Player  Matches  Innings  Not_Outs   Runs  High_Score  \
# 0         DG Bradman        52       80        10   6996         334
# 1           AC Voges        20       31         7   1485         269
# 2         RG Pollock        23       41         4   2256         274
# 3         GA Headley        22       40         4   2190         270
# 5        H Sutcliffe        54       84         9   4555         194
# 6          E Paynter        20       31         5   1540         243
# 7      KF Barrington        82      131        15   6806         256
# 8          ED Weekes        48       81         5   4455         207
# 9         WR Hammond        85      140        16   7249         336
# 10         GS Sobers        93      160        21   8032         365
# 11     KC Sangakkara       134      233        17  12400         319
# 12         SPD Smith       109      195        25   9685         239
# 13          JB Hobbs        61      102         7   5410         211
# ...

# %%
df['4s'].str.split(pat = '+').str[1]
# Out:
# 0
# 1     NaN
# 2
# 3
# 5
# 6
# 7
# 8
# 9
# 10
# 11    NaN
# 12    NaN
# 13
# 14
# 15
# 16    NaN
# 17    NaN
# 19
# 20    NaN
# 21
# 22    NaN
# 23    NaN
# 24
# 25
# 26    NaN
# 27    NaN
# 28
# 29    NaN
# 30    NaN
# 31    NaN
# 32    NaN
# 33
# 34    NaN
# 35    NaN
# 36    NaN
# 37
# 38    NaN
# 39    NaN
# 40    NaN
# 41    NaN
# 43    NaN
# 44    NaN
# 45
# 46
# 47    NaN
# 48    NaN
# 49    NaN
# 50
# 51
# 52    NaN
# 53    NaN
# 54    NaN
# 56    NaN
# 57
# 58
# 59
# 60    NaN
# 61
# 62
# 63    NaN
# 64
# 65
# 66
# Name: 4s, dtype: object

# %%
df['4s'] = df['4s'].str.split(pat = '+').str[1]

# %%
df
# Out:
#                Player  Matches  Innings  Not_Outs   Runs  High_Score  \
# 0         DG Bradman        52       80        10   6996         334
# 1           AC Voges        20       31         7   1485         269
# 2         RG Pollock        23       41         4   2256         274
# 3         GA Headley        22       40         4   2190         270
# 5        H Sutcliffe        54       84         9   4555         194
# 6          E Paynter        20       31         5   1540         243
# 7      KF Barrington        82      131        15   6806         256
# 8          ED Weekes        48       81         5   4455         207
# 9         WR Hammond        85      140        16   7249         336
# 10         GS Sobers        93      160        21   8032         365
# 11     KC Sangakkara       134      233        17  12400         319
# 12         SPD Smith       109      195        25   9685         239
# 13          JB Hobbs        61      102         7   5410         211
# ...

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Innings                  int64
# Not_Outs                 int64
# Runs                     int64
# High_Score               int32
# Average_Score          float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Start_Year               int32
# End_Year                 int32
# Country                 object
# dtype: object

# %%
df
# Out:
#                Player  Matches  Innings  Not_Outs   Runs  High_Score  \
# 0         DG Bradman        52       80        10   6996         334
# 1           AC Voges        20       31         7   1485         269
# 2         RG Pollock        23       41         4   2256         274
# 3         GA Headley        22       40         4   2190         270
# 5        H Sutcliffe        54       84         9   4555         194
# 6          E Paynter        20       31         5   1540         243
# 7      KF Barrington        82      131        15   6806         256
# 8          ED Weekes        48       81         5   4455         207
# 9         WR Hammond        85      140        16   7249         336
# 10         GS Sobers        93      160        21   8032         365
# 11     KC Sangakkara       134      233        17  12400         319
# 12         SPD Smith       109      195        25   9685         239
# 13          JB Hobbs        61      102         7   5410         211
# ...

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Innings                  int64
# Not_Outs                 int64
# Runs                     int64
# High_Score               int32
# Average_Score          float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Start_Year               int32
# End_Year                 int32
# Country                 object
# dtype: object

# %%
df["Balls_Faced"] = df["Balls_Faced"].str.split(pat = '+').str[0]

# %%
df["Balls_Faced"] = df["Balls_Faced"].astype("float")

# %%
df
# Out:
#                Player  Matches  Innings  Not_Outs   Runs  High_Score  \
# 0         DG Bradman        52       80        10   6996         334
# 1           AC Voges        20       31         7   1485         269
# 2         RG Pollock        23       41         4   2256         274
# 3         GA Headley        22       40         4   2190         270
# 5        H Sutcliffe        54       84         9   4555         194
# 6          E Paynter        20       31         5   1540         243
# 7      KF Barrington        82      131        15   6806         256
# 8          ED Weekes        48       81         5   4455         207
# 9         WR Hammond        85      140        16   7249         336
# 10         GS Sobers        93      160        21   8032         365
# 11     KC Sangakkara       134      233        17  12400         319
# 12         SPD Smith       109      195        25   9685         239
# 13          JB Hobbs        61      102         7   5410         211
# ...

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Innings                  int64
# Not_Outs                 int64
# Runs                     int64
# High_Score               int32
# Average_Score          float64
# Balls_Faced            float64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Start_Year               int32
# End_Year                 int32
# Country                 object
# dtype: object

# %%
df
# Out:
#                Player  Matches  Innings  Not_Outs   Runs  High_Score  \
# 0         DG Bradman        52       80        10   6996         334
# 1           AC Voges        20       31         7   1485         269
# 2         RG Pollock        23       41         4   2256         274
# 3         GA Headley        22       40         4   2190         270
# 5        H Sutcliffe        54       84         9   4555         194
# 6          E Paynter        20       31         5   1540         243
# 7      KF Barrington        82      131        15   6806         256
# 8          ED Weekes        48       81         5   4455         207
# 9         WR Hammond        85      140        16   7249         336
# 10         GS Sobers        93      160        21   8032         365
# 11     KC Sangakkara       134      233        17  12400         319
# 12         SPD Smith       109      195        25   9685         239
# 13          JB Hobbs        61      102         7   5410         211
# ...

# %%
df[df["Balls_Faced"].isna() ==1]
# Out:
#              Player  Matches  Innings  Not_Outs  Runs  High_Score  \
# 8        ED Weekes        48       81         5  4455         207
# 14      CL Walcott        44       74         7  3798         220
# 59  Hon.FS Jackson        20       33         4  1415         144
#
#     Average_Score  Balls_Faced  Batting_Strike_Rate  100  50  0 4s  6s  \
# 8           58.61          NaN                  0.0   15  19  6      2
# 14          56.68          NaN                  0.0   15  14  1     11
# 59          48.79          NaN                  0.0    5   6  3      0
#
#     Start_Year  End_Year Country
# 8         1948      1958      WI
# 14        1948      1960      WI
# 59        1893      1905     ENG

# %%
df["Balls_Faced"] = df["Balls_Faced"].fillna(0)

# %%
df["Balls_Faced"] = df["Balls_Faced"].astype("int")

# %%
pd.set_option('display.max_rows', None)

# %%
df
# Out:
#                Player  Matches  Innings  Not_Outs   Runs  High_Score  \
# 0         DG Bradman        52       80        10   6996         334
# 1           AC Voges        20       31         7   1485         269
# 2         RG Pollock        23       41         4   2256         274
# 3         GA Headley        22       40         4   2190         270
# 5        H Sutcliffe        54       84         9   4555         194
# 6          E Paynter        20       31         5   1540         243
# 7      KF Barrington        82      131        15   6806         256
# 8          ED Weekes        48       81         5   4455         207
# 9         WR Hammond        85      140        16   7249         336
# 10         GS Sobers        93      160        21   8032         365
# 11     KC Sangakkara       134      233        17  12400         319
# 12         SPD Smith       109      195        25   9685         239
# 13          JB Hobbs        61      102         7   5410         211
# ...

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Innings                  int64
# Not_Outs                 int64
# Runs                     int64
# High_Score               int32
# Average_Score          float64
# Balls_Faced              int32
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Start_Year               int32
# End_Year                 int32
# Country                 object
# dtype: object

# %%
df['4s'].str.split(pat = "+")

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Innings                  int64
# Not_Outs                 int64
# Runs                     int64
# High_Score               int32
# Average_Score          float64
# Balls_Faced              int32
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                      object
# 6s                      object
# Start_Year               int32
# End_Year                 int32
# Country                 object
# dtype: object

# %%
#create Career_Length field using start_year and end_year fields

# %%
df["Career_Length"] = df["End_Year"] - df["Start_Year"]

# %%
#Average career length

# %%
df["Career_Length"].mean()
# Out:
# 13.031746031746032

# %%
#Average batting strike rate who played over 10 years

# %%
df[df["Career_Length"] > 10] ["Batting_Strike_Rate"].mean()
# Out:
# 47.95590909090909

# %%
#find the number of cricketers who played before 1960

# %%
df[df["Start_Year"] < 1960] ["Player"].count()
# Out:
# 23

# %%
#max highest inns score by country

# %%
df.groupby("Country") ["High_Score"].max().to_frame("HighScoreByCountry").reset_index().sort_values("HighScoreByCountry", ascending = False
                                                                                                )
# Out:
#     Country  HighScoreByCountry
# 5    ICC/WI                 400
# 0       AUS                 380
# 10       SL                 374
# 11       WI                 365
# 1       ENG                 364
# 3   ICC/PAK                 329
# 2   ICC/IND                 319
# 8       PAK                 313
# 9        SA                 278
# 4    ICC/SA                 277
# 6       IND                 254
# 7        NZ                 251
# 12      ZIM                 232

# %%
# Hundreds, fifties, ducks AVG by country

# %%
df.groupby("Country") [["100", "50", "0"]].mean()
# Out:
#                100         50          0
# Country
# AUS      20.625000  28.375000   8.562500
# ENG      12.692308  21.230769   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       18.500000  22.000000   6.000000
# PAK      17.600000  23.600000   7.800000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
